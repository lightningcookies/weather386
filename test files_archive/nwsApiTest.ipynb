# %%
import requests
import pandas as pd

# %%
url = "https://api.weather.gov/points/40.76,-110.876"
x = requests.get(url)
print(x.text)
data = x.json()
# Out:
# {
#     "@context": [
#         "https://geojson.org/geojson-ld/geojson-context.jsonld",
#         {
#             "@version": "1.1",
#             "wx": "https://api.weather.gov/ontology#",
#             "s": "https://schema.org/",
#             "geo": "http://www.opengis.net/ont/geosparql#",
#             "unit": "http://codes.wmo.int/common/unit/",
#             "@vocab": "https://api.weather.gov/ontology#",
#             "geometry": {
#                 "@id": "s:GeoCoordinates",
#                 "@type": "geo:wktLiteral"
#             },
#             "city": "s:addressLocality",
#             "state": "s:addressRegion",
#             "distance": {
#                 "@id": "s:Distance",
#                 "@type": "s:QuantitativeValue"
#             },
#             "bearing": {
#                 "@type": "s:QuantitativeValue"
#             },
#             "value": {
#                 "@id": "s:value"
#             },
#             "unitCode": {
#                 "@id": "s:unitCode",
#                 "@type": "@id"
#             },
#             "forecastOffice": {
#                 "@type": "@id"
#             },
#             "forecastGridData": {
#                 "@type": "@id"
#             },
#             "publicZone": {
#                 "@type": "@id"
#             },
#             "county": {
#                 "@type": "@id"
#             }
#         }
#     ],
#     "id": "https://api.weather.gov/points/40.76,-110.876",
#     "type": "Feature",
#     "geometry": {
#         "type": "Point",
#         "coordinates": [
#             -110.876,
#             40.759999999999998
#         ]
#     },
#     "properties": {
#         "@id": "https://api.weather.gov/points/40.76,-110.876",
#         "@type": "wx:Point",
#         "cwa": "SLC",
#         "forecastOffice": "https://api.weather.gov/offices/SLC",
#         "gridId": "SLC",
#         "gridX": 135,
#         "gridY": 171,
#         "forecast": "https://api.weather.gov/gridpoints/SLC/135,171/forecast",
#         "forecastHourly": "https://api.weather.gov/gridpoints/SLC/135,171/forecast/hourly",
#         "forecastGridData": "https://api.weather.gov/gridpoints/SLC/135,171",
#         "observationStations": "https://api.weather.gov/gridpoints/SLC/135,171/stations",
#         "relativeLocation": {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -111.235865,
#                     40.642161999999999
#                 ]
#             },
#             "properties": {
#                 "city": "Samak",
#                 "state": "UT",
#                 "distance": {
#                     "unitCode": "wmoUnit:m",
#                     "value": 33045.192719801998
#                 },
#                 "bearing": {
#                     "unitCode": "wmoUnit:degree_(angle)",
#                     "value": 66
#                 }
#             }
#         },
#         "forecastZone": "https://api.weather.gov/zones/forecast/UTZ112",
#         "county": "https://api.weather.gov/zones/county/UTC043",
#         "fireWeatherZone": "https://api.weather.gov/zones/fire/UTZ480",
#         "timeZone": "America/Denver",
#         "radarStation": "KMTX"
#     }
# }

# %%
# FORECAST
forecast_url = data['properties']['forecast']
y = requests.get(forecast_url)
#print(y.text)

forecast = y.json()

forecast_data = forecast['properties']['periods']

df = pd.DataFrame(forecast_data)

print(df)
# Out:
#     number             name                  startTime  \
# 0        1          Tonight  2023-12-11T20:00:00-07:00
# 1        2          Tuesday  2023-12-12T06:00:00-07:00
# 2        3    Tuesday Night  2023-12-12T18:00:00-07:00
# 3        4        Wednesday  2023-12-13T06:00:00-07:00
# 4        5  Wednesday Night  2023-12-13T18:00:00-07:00
# 5        6         Thursday  2023-12-14T06:00:00-07:00
# 6        7   Thursday Night  2023-12-14T18:00:00-07:00
# 7        8           Friday  2023-12-15T06:00:00-07:00
# 8        9     Friday Night  2023-12-15T18:00:00-07:00
# 9       10         Saturday  2023-12-16T06:00:00-07:00
# 10      11   Saturday Night  2023-12-16T18:00:00-07:00
# 11      12           Sunday  2023-12-17T06:00:00-07:00
# 12      13     Sunday Night  2023-12-17T18:00:00-07:00
# 13      14           Monday  2023-12-18T06:00:00-07:00
#
#                       endTime  isDaytime  temperature temperatureUnit  \
# 0   2023-12-12T06:00:00-07:00      False           15               F
# 1   2023-12-12T18:00:00-07:00       True           31               F
# 2   2023-12-13T06:00:00-07:00      False           14               F
# 3   2023-12-13T18:00:00-07:00       True           30               F
# 4   2023-12-14T06:00:00-07:00      False           13               F
# 5   2023-12-14T18:00:00-07:00       True           32               F
# 6   2023-12-15T06:00:00-07:00      False           13               F
# 7   2023-12-15T18:00:00-07:00       True           37               F
# 8   2023-12-16T06:00:00-07:00      False           19               F
# 9   2023-12-16T18:00:00-07:00       True           39               F
# 10  2023-12-17T06:00:00-07:00      False           20               F
# 11  2023-12-17T18:00:00-07:00       True           39               F
# 12  2023-12-18T06:00:00-07:00      False           20               F
# 13  2023-12-18T18:00:00-07:00       True           36               F
#
#    temperatureTrend                      probabilityOfPrecipitation  \
# 0            rising  {'unitCode': 'wmoUnit:percent', 'value': None}
# 1           falling  {'unitCode': 'wmoUnit:percent', 'value': None}
# 2            rising  {'unitCode': 'wmoUnit:percent', 'value': None}
# 3              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 4              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 5              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 6              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 7              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 8              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 9              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 10             None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 11             None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 12             None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 13             None  {'unitCode': 'wmoUnit:percent', 'value': None}
#
#                                              dewpoint  \
# 0   {'unitCode': 'wmoUnit:degC', 'value': -14.4444...
# 1   {'unitCode': 'wmoUnit:degC', 'value': -6.66666...
# 2   {'unitCode': 'wmoUnit:degC', 'value': -9.44444...
# 3   {'unitCode': 'wmoUnit:degC', 'value': -6.11111...
# 4   {'unitCode': 'wmoUnit:degC', 'value': -8.33333...
# 5   {'unitCode': 'wmoUnit:degC', 'value': -7.22222...
# 6          {'unitCode': 'wmoUnit:degC', 'value': -10}
# 7   {'unitCode': 'wmoUnit:degC', 'value': -6.11111...
# 8   {'unitCode': 'wmoUnit:degC', 'value': -9.44444...
# 9   {'unitCode': 'wmoUnit:degC', 'value': -5.55555...
# 10  {'unitCode': 'wmoUnit:degC', 'value': -9.44444...
# 11  {'unitCode': 'wmoUnit:degC', 'value': -6.11111...
# 12         {'unitCode': 'wmoUnit:degC', 'value': -10}
# 13  {'unitCode': 'wmoUnit:degC', 'value': -6.11111...
#
#                                 relativeHumidity    windSpeed windDirection  \
# 0   {'unitCode': 'wmoUnit:percent', 'value': 62}       10 mph           SSE
# 1   {'unitCode': 'wmoUnit:percent', 'value': 81}   6 to 9 mph           SSE
# 2   {'unitCode': 'wmoUnit:percent', 'value': 84}  6 to 10 mph           ESE
# 3   {'unitCode': 'wmoUnit:percent', 'value': 86}  7 to 10 mph           SSE
# 4   {'unitCode': 'wmoUnit:percent', 'value': 87}        7 mph           ESE
# 5   {'unitCode': 'wmoUnit:percent', 'value': 77}        8 mph           WSW
# 6   {'unitCode': 'wmoUnit:percent', 'value': 76}        8 mph           ESE
# 7   {'unitCode': 'wmoUnit:percent', 'value': 66}        7 mph           SSE
# 8   {'unitCode': 'wmoUnit:percent', 'value': 66}        9 mph            SE
# 9   {'unitCode': 'wmoUnit:percent', 'value': 58}        9 mph             S
# 10  {'unitCode': 'wmoUnit:percent', 'value': 57}        9 mph             S
# 11  {'unitCode': 'wmoUnit:percent', 'value': 59}        9 mph           SSW
# 12  {'unitCode': 'wmoUnit:percent', 'value': 59}       10 mph           SSE
# 13  {'unitCode': 'wmoUnit:percent', 'value': 65}       12 mph            SW
#
#                                                  icon  \
# 0   https://api.weather.gov/icons/land/night/bkn?s...
# 1   https://api.weather.gov/icons/land/day/bkn?siz...
# 2   https://api.weather.gov/icons/land/night/bkn?s...
# 3   https://api.weather.gov/icons/land/day/sct?siz...
# 4   https://api.weather.gov/icons/land/night/few?s...
# 5   https://api.weather.gov/icons/land/day/few?siz...
# 6   https://api.weather.gov/icons/land/night/few?s...
# 7   https://api.weather.gov/icons/land/day/few?siz...
# 8   https://api.weather.gov/icons/land/night/sct?s...
# 9   https://api.weather.gov/icons/land/day/bkn?siz...
# 10  https://api.weather.gov/icons/land/night/few?s...
# 11  https://api.weather.gov/icons/land/day/few?siz...
# 12  https://api.weather.gov/icons/land/night/sct?s...
# 13  https://api.weather.gov/icons/land/day/snow?si...
#
#                shortForecast  \
# 0              Mostly Cloudy
# 1              Mostly Cloudy
# 2              Mostly Cloudy
# 3               Mostly Sunny
# 4               Mostly Clear
# 5                      Sunny
# 6               Mostly Clear
# 7                      Sunny
# 8              Partly Cloudy
# 9               Partly Sunny
# 10              Mostly Clear
# 11                     Sunny
# 12             Partly Cloudy
# 13  Slight Chance Light Snow
#
#                                      detailedForecast
# 0   Mostly cloudy. Low around 15, with temperature...
# 1   Mostly cloudy. High near 31, with temperatures...
# 2   Mostly cloudy. Low around 14, with temperature...
# 3   Mostly sunny, with a high near 30. Wind chill ...
# 4   Mostly clear, with a low around 13. East south...
# 5                         Sunny, with a high near 32.
# 6                 Mostly clear, with a low around 13.
# 7                         Sunny, with a high near 37.
# 8                Partly cloudy, with a low around 19.
# 9                  Partly sunny, with a high near 39.
# 10                Mostly clear, with a low around 20.
# 11                        Sunny, with a high near 39.
# 12               Partly cloudy, with a low around 20.
# 13  A slight chance of snow between 11am and 5pm. ...

# %%
#FORECAST HOURLY
forecast_url = data['properties']['forecastHourly']
z = requests.get(forecast_url)

#print(z.text)

forecast_hr = z.json()
#print(forecast_hr)

forecast_data_hr = forecast_hr['properties']['periods']

df = pd.DataFrame(forecast_data_hr)

print(df)
# Out:
#      number name                  startTime                    endTime  \
# 0         1       2023-11-20T16:00:00-06:00  2023-11-20T17:00:00-06:00
# 1         2       2023-11-20T17:00:00-06:00  2023-11-20T18:00:00-06:00
# 2         3       2023-11-20T18:00:00-06:00  2023-11-20T19:00:00-06:00
# 3         4       2023-11-20T19:00:00-06:00  2023-11-20T20:00:00-06:00
# 4         5       2023-11-20T20:00:00-06:00  2023-11-20T21:00:00-06:00
# ..      ...  ...                        ...                        ...
# 151     152       2023-11-26T23:00:00-06:00  2023-11-27T00:00:00-06:00
# 152     153       2023-11-27T00:00:00-06:00  2023-11-27T01:00:00-06:00
# 153     154       2023-11-27T01:00:00-06:00  2023-11-27T02:00:00-06:00
# 154     155       2023-11-27T02:00:00-06:00  2023-11-27T03:00:00-06:00
# 155     156       2023-11-27T03:00:00-06:00  2023-11-27T04:00:00-06:00
#
#      isDaytime  temperature temperatureUnit temperatureTrend  \
# 0         True           43               F             None
# 1         True           43               F             None
# 2        False           42               F             None
# 3        False           42               F             None
# 4        False           41               F             None
# ..         ...          ...             ...              ...
# 151      False           28               F             None
# 152      False           27               F             None
# 153      False           26               F             None
# 154      False           26               F             None
# 155      False           25               F             None
#
#                        probabilityOfPrecipitation  \
# 0    {'unitCode': 'wmoUnit:percent', 'value': 57}
# 1    {'unitCode': 'wmoUnit:percent', 'value': 49}
# 2    {'unitCode': 'wmoUnit:percent', 'value': 41}
# 3    {'unitCode': 'wmoUnit:percent', 'value': 35}
# 4    {'unitCode': 'wmoUnit:percent', 'value': 28}
# ..                                            ...
# 151   {'unitCode': 'wmoUnit:percent', 'value': 1}
# 152   {'unitCode': 'wmoUnit:percent', 'value': 0}
# 153   {'unitCode': 'wmoUnit:percent', 'value': 0}
# 154   {'unitCode': 'wmoUnit:percent', 'value': 0}
# 155   {'unitCode': 'wmoUnit:percent', 'value': 0}
#
#                                               dewpoint  \
# 0    {'unitCode': 'wmoUnit:degC', 'value': 5.555555...
# 1    {'unitCode': 'wmoUnit:degC', 'value': 5.555555...
# 2    {'unitCode': 'wmoUnit:degC', 'value': 5.555555...
# 3    {'unitCode': 'wmoUnit:degC', 'value': 5.555555...
# 4             {'unitCode': 'wmoUnit:degC', 'value': 5}
# ..                                                 ...
# 151  {'unitCode': 'wmoUnit:degC', 'value': -4.44444...
# 152  {'unitCode': 'wmoUnit:degC', 'value': -4.44444...
# 153          {'unitCode': 'wmoUnit:degC', 'value': -5}
# 154          {'unitCode': 'wmoUnit:degC', 'value': -5}
# 155  {'unitCode': 'wmoUnit:degC', 'value': -5.55555...
#
#                                   relativeHumidity windSpeed windDirection  \
# 0     {'unitCode': 'wmoUnit:percent', 'value': 95}    15 mph             N
# 1     {'unitCode': 'wmoUnit:percent', 'value': 97}    15 mph             N
# 2     {'unitCode': 'wmoUnit:percent', 'value': 98}    15 mph             N
# 3    {'unitCode': 'wmoUnit:percent', 'value': 100}    15 mph             N
# 4    {'unitCode': 'wmoUnit:percent', 'value': 100}    15 mph             N
# ..                                             ...       ...           ...
# 151   {'unitCode': 'wmoUnit:percent', 'value': 85}    10 mph             W
# 152   {'unitCode': 'wmoUnit:percent', 'value': 88}    10 mph             W
# 153   {'unitCode': 'wmoUnit:percent', 'value': 88}    10 mph             W
# 154   {'unitCode': 'wmoUnit:percent', 'value': 88}    10 mph            NW
# 155   {'unitCode': 'wmoUnit:percent', 'value': 88}    10 mph            NW
#
#                                                   icon      shortForecast  \
# 0    https://api.weather.gov/icons/land/day/rain,57...  Light Rain Likely
# 1    https://api.weather.gov/icons/land/day/rain,49...  Chance Light Rain
# 2    https://api.weather.gov/icons/land/night/rain,...  Chance Light Rain
# 3    https://api.weather.gov/icons/land/night/rain,...  Chance Light Rain
# 4    https://api.weather.gov/icons/land/night/rain,...  Chance Light Rain
# ..                                                 ...                ...
# 151  https://api.weather.gov/icons/land/night/few,1...       Mostly Clear
# 152  https://api.weather.gov/icons/land/night/few,0...       Mostly Clear
# 153  https://api.weather.gov/icons/land/night/few,0...       Mostly Clear
# 154  https://api.weather.gov/icons/land/night/few,0...       Mostly Clear
# 155  https://api.weather.gov/icons/land/night/few,0...       Mostly Clear
#
#     detailedForecast
# 0
# 1
# 2
# 3
# 4
# ..               ...
# 151
# 152
# 153
# 154
# 155
#
# [156 rows x 16 columns]

# %% [markdown]
# * think about time zones and adjusting for the user's timezone.
# * omit times that have already passed?
# * a big part is going to be making sure the pipeline is clean from the beginning.

# %%
#function layout

#coordinate <- get_coordinate('SLC')

#forecast_df <- get_forecast(coordinate)

# could be get_past 
#history_df <- get_history(coordinate)

# Needs new name.  get_all
#combined_df <- get_h_f(coordinate) #more important



#plots <- weather_plots(df)

#plots['temperature']


#recap function

#recap = weather_recap(df)

# %%
#FORECAST GRID DATA
forecast_url = data['properties']['forecastGridData']
g = requests.get(forecast_url)

#print(g.text)

forecast_grid = g.json()
#print(forecast_hr)

forecast_grid_temp = forecast_grid['properties']['temperature']['values']
forecast_grid_dewpoint = forecast_grid['properties']['dewpoint']['values']
forecast_grid_maxTemperature = forecast_grid['properties']['maxTemperature']['values']
forecast_grid_minTemperature = forecast_grid['properties']['minTemperature']['values']
forecast_grid_relativeHumidity = forecast_grid['properties']['relativeHumidity']['values']
#apparentTemp
#wetBulbGlobeTemperature
#heatIndex
#windChill
#skyCover
forecast_grid_windDirection = forecast_grid['properties']['windDirection']['values']
forecast_grid_windSpeed = forecast_grid['properties']['windSpeed']['values']
#windGust
#weather
#probabilityOfPrecipitation
forecast_grid_precip = forecast_grid['properties']['quantitativePrecipitation']['values']
#ice accumulation
forecast_grid_snowfallAmount = forecast_grid['properties']['snowfallAmount']['values']
#snowLevel
#ceilingHeight
#visibility
#transportWindSpeed
#transportWindDirection
#mixingHeight
#hainesIndex
#lightningActivityLevel
#** many empty df**


df_temp = pd.DataFrame(forecast_grid_temp)
df_dewpoint = pd.DataFrame(forecast_grid_dewpoint)
df_maxTemperature = pd.DataFrame(forecast_grid_maxTemperature)
df_minTemperature = pd.DataFrame(forecast_grid_minTemperature)
df_relativeHumidity = pd.DataFrame(forecast_grid_relativeHumidity)
df_windDirection = pd.DataFrame(forecast_grid_windDirection)
df_windSpeed = pd.DataFrame(forecast_grid_windSpeed)
df_precip = pd.DataFrame(forecast_grid_precip)
df_snowfall = pd.DataFrame(forecast_grid_snowfallAmount)

dataframes = [
    df_temp, 
    df_dewpoint, 
    df_maxTemperature, 
    df_minTemperature, 
    df_relativeHumidity, 
    df_windDirection, 
    df_windSpeed, 
    df_precip, 
    df_snowfall
]

# %%
#df_dewpoint[['DateTime', 'Duration']] = df_dewpoint['validTime'].str.split('/PT', expand=True)
#df_windSpeed[['DateTime', 'Duration']] = df_windSpeed['validTime'].str.split('/PT', expand=True)

# %%
import os

# Directory where the CSV files will be saved
output_directory = 'forecast_csv'

dataframes_dict = {
    'df_temp': df_temp,
    'df_dewpoint': df_dewpoint,
    'df_maxTemperature': df_maxTemperature,
    'df_minTemperature': df_minTemperature,
    'df_relativeHumidity': df_relativeHumidity,
    'df_windDirection': df_windDirection,
    'df_windSpeed': df_windSpeed,
    'df_precip': df_precip,
    'df_snowfall': df_snowfall
}
for name, df in dataframes_dict.items():
    csv_filename = os.path.join(output_directory, f'{name}.csv')
    df.to_csv(csv_filename, index=False)

# %%
dataframes_dict = {
    'df_temp': df_temp,
    'df_dewpoint': df_dewpoint,
    'df_maxTemperature': df_maxTemperature,
    'df_minTemperature': df_minTemperature,
    'df_relativeHumidity': df_relativeHumidity,
    'df_windDirection': df_windDirection,
    'df_windSpeed': df_windSpeed,
    'df_precip': df_precip,
    'df_snowfall': df_snowfall
}

# Initialize a list to hold the dataframes
dfs = []

# Add each dataframe to the list
for name, df in dataframes_dict.items():
    # Assuming each DataFrame has a 'validTime' column and other unique columns
    df = df.rename(columns={col: f"{name}_{col}" for col in df.columns if col != 'validTime'})
    dfs.append(df)

# Merge all dataframes on 'validTime' column
combined_df = pd.concat(dfs, axis=1)
combined_df = combined_df.loc[:,~combined_df.columns.duplicated()]

# Now you can save the combined dataframe
combined_df.to_csv('combined_dataframe.csv', index=False)

# %%
for df in dataframes:
    df[['DateTime', 'Duration']] = df['validTime'].str.split('/PT', expand=True)
    df['Duration'] = 'PT' + df['Duration']

# %%
import matplotlib.pyplot as plt
#plt.plot(df_dewpoint['DateTime'],df_dewpoint['value'])
plt.plot(df_windSpeed['DateTime'],df_windSpeed['value'])
