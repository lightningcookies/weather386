# %%
import requests
import pandas as pd

# %%
url = "https://api.weather.gov/points/39.7456,-97.0892"
x = requests.get(url)
print(x.text)
data = x.json()
# Out:
# {
#     "@context": [
#         "https://geojson.org/geojson-ld/geojson-context.jsonld",
#         {
#             "@version": "1.1",
#             "wx": "https://api.weather.gov/ontology#",
#             "s": "https://schema.org/",
#             "geo": "http://www.opengis.net/ont/geosparql#",
#             "unit": "http://codes.wmo.int/common/unit/",
#             "@vocab": "https://api.weather.gov/ontology#",
#             "geometry": {
#                 "@id": "s:GeoCoordinates",
#                 "@type": "geo:wktLiteral"
#             },
#             "city": "s:addressLocality",
#             "state": "s:addressRegion",
#             "distance": {
#                 "@id": "s:Distance",
#                 "@type": "s:QuantitativeValue"
#             },
#             "bearing": {
#                 "@type": "s:QuantitativeValue"
#             },
#             "value": {
#                 "@id": "s:value"
#             },
#             "unitCode": {
#                 "@id": "s:unitCode",
#                 "@type": "@id"
#             },
#             "forecastOffice": {
#                 "@type": "@id"
#             },
#             "forecastGridData": {
#                 "@type": "@id"
#             },
#             "publicZone": {
#                 "@type": "@id"
#             },
#             "county": {
#                 "@type": "@id"
#             }
#         }
#     ],
#     "id": "https://api.weather.gov/points/39.7456,-97.0892",
#     "type": "Feature",
#     "geometry": {
#         "type": "Point",
#         "coordinates": [
#             -97.089200000000005,
#             39.745600000000003
#         ]
#     },
#     "properties": {
#         "@id": "https://api.weather.gov/points/39.7456,-97.0892",
#         "@type": "wx:Point",
#         "cwa": "TOP",
#         "forecastOffice": "https://api.weather.gov/offices/TOP",
#         "gridId": "TOP",
#         "gridX": 32,
#         "gridY": 81,
#         "forecast": "https://api.weather.gov/gridpoints/TOP/32,81/forecast",
#         "forecastHourly": "https://api.weather.gov/gridpoints/TOP/32,81/forecast/hourly",
#         "forecastGridData": "https://api.weather.gov/gridpoints/TOP/32,81",
#         "observationStations": "https://api.weather.gov/gridpoints/TOP/32,81/stations",
#         "relativeLocation": {
#             "type": "Feature",
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -97.086661000000007,
#                     39.679375999999998
#                 ]
#             },
#             "properties": {
#                 "city": "Linn",
#                 "state": "KS",
#                 "distance": {
#                     "unitCode": "wmoUnit:m",
#                     "value": 7366.9851976443997
#                 },
#                 "bearing": {
#                     "unitCode": "wmoUnit:degree_(angle)",
#                     "value": 358
#                 }
#             }
#         },
#         "forecastZone": "https://api.weather.gov/zones/forecast/KSZ009",
#         "county": "https://api.weather.gov/zones/county/KSC201",
#         "fireWeatherZone": "https://api.weather.gov/zones/fire/KSZ009",
#         "timeZone": "America/Chicago",
#         "radarStation": "KTWX"
#     }
# }

# %%
forecast_url = data['properties']['forecast']
y = requests.get(forecast_url)
#print(y.text)

forecast = y.json()

forecast_data = forecast['properties']['periods']

df = pd.DataFrame(forecast_data)

print(df)
# Out:
#     number             name                  startTime  \
# 0        1          Tonight  2023-10-22T20:00:00-05:00
# 1        2           Monday  2023-10-23T06:00:00-05:00
# 2        3     Monday Night  2023-10-23T18:00:00-05:00
# 3        4          Tuesday  2023-10-24T06:00:00-05:00
# 4        5    Tuesday Night  2023-10-24T18:00:00-05:00
# 5        6        Wednesday  2023-10-25T06:00:00-05:00
# 6        7  Wednesday Night  2023-10-25T18:00:00-05:00
# 7        8         Thursday  2023-10-26T06:00:00-05:00
# 8        9   Thursday Night  2023-10-26T18:00:00-05:00
# 9       10           Friday  2023-10-27T06:00:00-05:00
# 10      11     Friday Night  2023-10-27T18:00:00-05:00
# 11      12         Saturday  2023-10-28T06:00:00-05:00
# 12      13   Saturday Night  2023-10-28T18:00:00-05:00
# 13      14           Sunday  2023-10-29T06:00:00-05:00
#
#                       endTime  isDaytime  temperature temperatureUnit  \
# 0   2023-10-23T06:00:00-05:00      False           59               F
# 1   2023-10-23T18:00:00-05:00       True           86               F
# 2   2023-10-24T06:00:00-05:00      False           65               F
# 3   2023-10-24T18:00:00-05:00       True           76               F
# 4   2023-10-25T06:00:00-05:00      False           63               F
# 5   2023-10-25T18:00:00-05:00       True           74               F
# 6   2023-10-26T06:00:00-05:00      False           57               F
# 7   2023-10-26T18:00:00-05:00       True           71               F
# 8   2023-10-27T06:00:00-05:00      False           37               F
# 9   2023-10-27T18:00:00-05:00       True           50               F
# 10  2023-10-28T06:00:00-05:00      False           34               F
# 11  2023-10-28T18:00:00-05:00       True           52               F
# 12  2023-10-29T06:00:00-05:00      False           32               F
# 13  2023-10-29T18:00:00-05:00       True           43               F
#
#    temperatureTrend                      probabilityOfPrecipitation  \
# 0              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 1              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 2              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 3              None    {'unitCode': 'wmoUnit:percent', 'value': 40}
# 4              None    {'unitCode': 'wmoUnit:percent', 'value': 60}
# 5              None    {'unitCode': 'wmoUnit:percent', 'value': 50}
# 6              None    {'unitCode': 'wmoUnit:percent', 'value': 50}
# 7              None    {'unitCode': 'wmoUnit:percent', 'value': 40}
# 8              None    {'unitCode': 'wmoUnit:percent', 'value': 30}
# 9              None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 10             None  {'unitCode': 'wmoUnit:percent', 'value': None}
# 11             None    {'unitCode': 'wmoUnit:percent', 'value': 40}
# 12             None    {'unitCode': 'wmoUnit:percent', 'value': 50}
# 13             None    {'unitCode': 'wmoUnit:percent', 'value': 50}
#
#                                              dewpoint  \
# 0   {'unitCode': 'wmoUnit:degC', 'value': 11.66666...
# 1           {'unitCode': 'wmoUnit:degC', 'value': 15}
# 2   {'unitCode': 'wmoUnit:degC', 'value': 16.66666...
# 3   {'unitCode': 'wmoUnit:degC', 'value': 18.33333...
# 4   {'unitCode': 'wmoUnit:degC', 'value': 18.88888...
# 5   {'unitCode': 'wmoUnit:degC', 'value': 19.44444...
# 6   {'unitCode': 'wmoUnit:degC', 'value': 18.33333...
# 7   {'unitCode': 'wmoUnit:degC', 'value': 16.66666...
# 8   {'unitCode': 'wmoUnit:degC', 'value': 14.44444...
# 9   {'unitCode': 'wmoUnit:degC', 'value': 2.222222...
# 10  {'unitCode': 'wmoUnit:degC', 'value': 1.666666...
# 11           {'unitCode': 'wmoUnit:degC', 'value': 5}
# 12  {'unitCode': 'wmoUnit:degC', 'value': 5.555555...
# 13  {'unitCode': 'wmoUnit:degC', 'value': 1.666666...
#
#                                  relativeHumidity     windSpeed windDirection  \
# 0    {'unitCode': 'wmoUnit:percent', 'value': 74}        15 mph             S
# 1    {'unitCode': 'wmoUnit:percent', 'value': 86}  10 to 20 mph             S
# 2    {'unitCode': 'wmoUnit:percent', 'value': 84}  15 to 20 mph             S
# 3    {'unitCode': 'wmoUnit:percent', 'value': 90}  15 to 20 mph             S
# 4   {'unitCode': 'wmoUnit:percent', 'value': 100}        15 mph             S
# 5   {'unitCode': 'wmoUnit:percent', 'value': 100}  15 to 20 mph             S
# 6   {'unitCode': 'wmoUnit:percent', 'value': 100}  15 to 20 mph             S
# 7   {'unitCode': 'wmoUnit:percent', 'value': 100}        15 mph             S
# 8    {'unitCode': 'wmoUnit:percent', 'value': 94}  15 to 20 mph            NE
# 9    {'unitCode': 'wmoUnit:percent', 'value': 87}  15 to 20 mph             N
# 10   {'unitCode': 'wmoUnit:percent', 'value': 95}  10 to 15 mph            NE
# 11   {'unitCode': 'wmoUnit:percent', 'value': 97}  10 to 15 mph            NE
# 12  {'unitCode': 'wmoUnit:percent', 'value': 100}        15 mph            NE
# 13  {'unitCode': 'wmoUnit:percent', 'value': 100}  15 to 20 mph             N
#
#                                                  icon  \
# 0   https://api.weather.gov/icons/land/night/sct?s...
# 1   https://api.weather.gov/icons/land/day/few?siz...
# 2   https://api.weather.gov/icons/land/night/few?s...
# 3   https://api.weather.gov/icons/land/day/rain_sh...
# 4   https://api.weather.gov/icons/land/night/tsra,...
# 5   https://api.weather.gov/icons/land/day/tsra,50...
# 6   https://api.weather.gov/icons/land/night/tsra,...
# 7   https://api.weather.gov/icons/land/day/tsra_sc...
# 8   https://api.weather.gov/icons/land/night/rain_...
# 9   https://api.weather.gov/icons/land/day/sct?siz...
# 10  https://api.weather.gov/icons/land/night/sct?s...
# 11  https://api.weather.gov/icons/land/day/rain_sh...
# 12  https://api.weather.gov/icons/land/night/rain_...
# 13  https://api.weather.gov/icons/land/day/rain_sh...
#
#                        shortForecast  \
# 0                      Partly Cloudy
# 1                              Sunny
# 2                       Mostly Clear
# 3                Chance Rain Showers
# 4   Showers And Thunderstorms Likely
# 5   Chance Showers And Thunderstorms
# 6   Chance Showers And Thunderstorms
# 7   Chance Showers And Thunderstorms
# 8                Chance Rain Showers
# 9                       Mostly Sunny
# 10                     Partly Cloudy
# 11               Chance Rain Showers
# 12               Chance Rain Showers
# 13               Chance Rain Showers
#
#                                      detailedForecast
# 0   Partly cloudy, with a low around 59. South win...
# 1   Sunny, with a high near 86. South wind 10 to 2...
# 2   Mostly clear, with a low around 65. South wind...
# 3   A chance of rain showers between 7am and 4pm, ...
# 4   Showers and thunderstorms likely before 1am, t...
# 5   A chance of showers and thunderstorms before 1...
# 6   A chance of showers and thunderstorms before 7...
# 7   A chance of showers and thunderstorms. Partly ...
# 8   A chance of rain showers before 1am. Partly cl...
# 9                  Mostly sunny, with a high near 50.
# 10               Partly cloudy, with a low around 34.
# 11  A chance of rain showers after 7am. Partly sun...
# 12  A chance of rain showers. Mostly cloudy, with ...
# 13  A chance of rain showers. Partly sunny, with a...
